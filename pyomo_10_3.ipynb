# %%
# %%time

from __future__ import division

from pyomo.environ import *

import random as ra

for l in range(10):
    

    Model = ConcreteModel()

    costumers = 10

    depots = 3

    nodes = costumers + depots

    Model.n =  RangeSet(1,nodes)

    Model.n0 = set (i for i in Model.n if i <= depots)

    Model.nc = set (i for i in Model.n if i > depots )




    #def x1  (Model,i):
    #    return ra.randint(50,150)
    #Model.x1 = Param( Model.n , initialize = x1)

    x1 = {}
    for i in Model.n:
        x1[i] = ra.randint(50,100)
    Model.x1 = Param(Model.n,initialize = x1)


    #def y1 (Model,i):
    #    return ra.randint(50,150)
    #Model.y1 = Param(Model.n,initialize = y1)

    y1 = {}
    for i in Model.n:
         y1[i] = ra.randint(50,100)
    Model.y1 = Param(Model.n,initialize = y1)


    #def d (Model,i):
    #    return ra.randint(50,150)
    #Model.d = Param(Model.nc,initialize = d)

    d = {}
    for i in Model.nc :
    #    if i > depots :
            d[i] = ra.randint(50,100)
    Model.d = Param(Model.nc,initialize = d)

    #def p (Model,i):
    #    return ra.randint(50,150)
    #Model.p = Param(Model.nc,initialize = p)

    p = {}
    for i in Model.nc :
    #    if i > depots :
            p[i] = ra.randint(50,100)
    Model.p = Param(Model.nc,initialize = p)


    #def fd (Model,i):
    #    return ra.randint(50,100)
    #Model.p = Param(Model.n0,initialize = fd)

    fd ={}
    for i in Model.n0 :
    #    if i <depots+1:
            fd[i] = ra.randint(10,50)
    Model.fd = Param(Model.n0,initialize = fd)



    cd = 500

    cv = 200

    fv =20

    def c  (Model,i,j):
        return ((x1[i]-x1[j])**2+ (y1[i]-y1[j])**2)**0.5
    Model.c = Param( Model.n,Model.n , initialize = c)

    #c ={}
    #for i in Model.n:
    #    for j in Model.n:
    #                c[i,j] = ((x1[i]-x1[j])**2+ (y1[i]-y1[j])**2)**0.5
    #
    #Model.c = Param(Model.n,Model.n ,initialize = c)

    #Model.zz = Var(within = Reals)
    #Model.z3 =set( Model.nc , Model.n0)

    Model.x  = Var(Model.n , Model.n , within = Binary)

    Model.y = Var(Model.n0  , within = Binary)

    Model.z = Var(Model.nc , Model.n0  , within = Binary)
  

    Model.v = Var(Model.n,Model.n , within = PositiveReals)

    Model.u = Var(Model.n,Model.n , within = PositiveReals)

    #for i in Model.n:
    #    for k in Model.n:
    #        Model.z =

    def _2 (Model,i):
        xij=0
        for j in Model.n:
            xij+=Model.x[i,j]
            return xij ==1
    Model._2 = Constraint(Model.nc,rule =_2)

    #def _2 (Model):
    #
    #    for i in Model.nc:
    #        xij=0
    #       for j in Model.n:
    #           xij+=Model.x[i,j]
    #        return xij ==1
    #Model._2 = Constraint(rule =_2)

    def _3 (Model,i):
        xij = 0
        xji = 0
        for j in Model.n:
            xij+=Model.x[i,j]
            xji+=Model.x[j,i]
            return xij == xji
    Model._3 = Constraint(Model.n,rule =_3)


    #def _3 (Model):
    #    for i in Model.n:
    #        xij=0
    #        xji=0
    #        for j in Model.n:
    #            xij+=Model.x[i,j]
    #            xji+=Model.x[j,i]
    #        return xij ==xji
    #Model._3 = Constraint(rule =_3)

    def _4 (Model,i):

            uij = 0
            uji = 0
            for j in Model.n:
                uji +=Model.u[j,i]
                uij +=Model.u[i,j]
            return uji - uij == Model.d[i]
    Model._4 = Constraint(Model.nc,rule =_4)

    #def _4 (Model):
    #    for i in Model.nc:
    #        uij = 0
    #        uji = 0
    #        for j in Model.n:
    #            uji +=Model.u[j,i]
    #            uij +=Model.u[i,j]
    #        return uji - uij == Model.d[i]
    #Model._4 = Constraint(rule =_4)

    def _5 (Model,i):

            vij = 0
            vji = 0
            for j in Model.n:
                vji +=Model.v[j,i]
                vij +=Model.v[i,j]
            return vji - vij == Model.p[i]
    Model._5 = Constraint(Model.nc,rule =_5)

    #def _5 (Model):
    #    for i in Model.nc:
    #        vij = 0
    #        vji = 0
    #        for j in Model.n:
    #            vji +=Model.v[j,i]
    #            vij +=Model.v[i,j]
    #        return vji - vij == Model.p[i]
    #Model._5 = Constraint(rule =_5)

    def _6 (Model,i):
        for j in Model.n:
                if i!= j:
                    return  Model.u[i,j] + Model.v[i,j] <=cv * Model.x[i,j]
    Model._6 = Constraint(Model.n,rule =_6)

    #def _6 (Model):
    #    for i in Model.n:
    #        for j in Model.n:
    #            if i!= j:
    #                return  Model.u[i,j] + Model.v[i,j] <=cv * Model.x[i,j]
    #Model._6 = Constraint(rule =_6)

    def _7 (Model,k):

            ukj = 0
            zjkdj = 0
            for j in Model.nc:
                ukj += Model.u[k,j]
                zjkdj +=Model.z[j,k]*Model.d[j]
            return ukj == zjkdj
    Model._7 = Constraint(Model.n0,rule =_7)

    #def _7 (Model):
    #    for k in Model.nc:
    #        ukj = 0
    #        zjkdj = 0
    #        for j in Model.nc:
    #            ukj += Model.u[k,j]
    #            zjkdj +=Model.z[j,k]*Model.d[j]
    #        return ukj == zjkdj
    #Model._7 = Constraint(rule =_7)

    def _8 (Model,k):


            ujk=0
            for j in Model.nc:
                ujk+=Model.u[j,k]
            return ujk == 0
    Model._8 = Constraint(Model.n0,rule =_8)

    #def _8 (Model):
    #
    #    for k in Model.n0:
    #        ujk=0
    #        for j in Model.nc:
    #            ujk+=Model.u[j,k]
    #        return ujk == 0
    #Model._8 = Constraint(rule =_8)

    #def _9 (Model,k):
    #    vjk = 0
    #    zjkpj = 0
    #    for j in Model.nc:
    #        vjk += Model.u[k,j]
    #        zjkpj += Model.z[j,k]*Model.p[j]
    #    return vjk == zjkpj
    #Model._9 = Constraint(Model.n0,rule =_9)

    def _9 (Model):
        for k in Model.n0:
            vjk = 0
            zjkpj = 0
            for j in Model.nc:
                vjk += Model.u[k,j]
                zjkpj +=Model.z[j,k]*Model.p[j]
            return vjk == zjkpj
    Model._9 = Constraint(rule =_9)

    #def _10 (Model,k):
    #
    #        vjk=0
    #        for j in Model.nc:
    #            vjk+=Model.v[j,k]
    #        return vjk == 0
    #Model._10 = Constraint(Model.n0,rule =_10)

    def _10 (Model,k):


            vjk=0
            for j in Model.nc:
                vjk+=Model.v[j,k]
            return vjk == 0
    Model._10 = Constraint(Model.n0,rule =_10)

    #def _10 (Model):
    #
    #    for k in Model.n0:
    #        vjk=0
    #        for j in Model.nc:
    #            vjk+=Model.v[j,k]
    #        return vjk == 0
    #Model._10 = Constraint(rule =_10)

    def _11 (Model,i,j):

                return Model.u[i,j] <= (cv - Model.d[i])* Model.x[i,j]
    Model._11 = Constraint(Model.nc,Model.n,rule =_11)



    #def _11 (Model):
    #    for j in Model.n:
    #        for i in Model.nc:
    #            return Model.u[i,j] <= (cv - Model.d[i])* Model.x[i,j]
    #Model._11 = Constraint(rule =_11)

    def _12 (Model,i,j):

                return Model.v[i,j] <= (cv - Model.p[i])* Model.x[i,j]
    Model._12 = Constraint(Model.nc,Model.n,rule =_12)

    #def _12 (Model):
    #    for i in Model.nc:
    #        for j in Model.n:
    #            return Model.v[i,j] <= (cv - Model.p[i])* Model.x[i,j]
    #Model._12 = Constraint(rule =_12)

    #def _13 (Model,i):
    #    for j in Model.nc:
    #            return Model.u[i,j] >= Model.d[j]*Model.x[i,j]
    #Model._13 = Constraint(Model.n,rule =_13)

    def _13 (Model):
        for j in Model.nc:
            for i in Model.n:
                return Model.u[i,j] >= Model.d[j]*Model.x[i,j]
    Model._13 = Constraint(rule =_13)

    #def _14 (Model,i,j):
    #
    #            return Model.u[i,j] >= Model.d[j]*Model.x[i,j]
    #Model._14 = Constraint(Model.nc,Model.n,rule =_14)

    def _14 (Model):
        for j in Model.nc:
            for i in Model.n:
                return Model.v[i,j] >= Model.p[j] * Model.x[i,j]
    Model._14 = Constraint(rule =_14)

    def _15 (Model):

        for i in Model.nc:
            zik=0
            for k in Model.n0:
                zik += Model.z[i,k]
            return zik == 1
    Model._15 = Constraint(rule =_15)

    def _16 (Model):
        for k in Model.n0:
            dizik = 0
            for i in Model.nc:
                dizik += Model.d[i] * Model.z[i,k]
            return dizik <=cd * Model.y[k]
    Model._16 = Constraint(rule =_16)

    def _17 (Model):
        for k in Model.n0:
            pizik = 0
            for i in Model.nc:
                pizik += Model.d[i] * Model.z[i,k]
            return pizik <=cd * Model.y[k]
    Model._17 = Constraint(rule =_17)

    def _18 (Model):
        for k in Model.n0:
            for i in Model.nc:
                return Model.x[i,k] <= Model.z[i,k]
    Model._18 = Constraint(rule =_18)

    def _19 (Model):
        for k in Model.n0:
            for i in Model.nc:
                return Model.x[k,i] <= Model.z[i,k]
    Model._19 = Constraint(rule =_19)

    def _20 (Model):
        for k in Model.n0:
            for i in Model.nc:
                for j in Model.nc:
                    if i!=j :

                        zjm = 0
                        for m in Model.n0:
                            if m != k:
                                zjm += Model.z[j,m]
                        return Model.x[i,j]+Model.z[i,k] + zjm <=2
    Model._20 = Constraint(rule =_20)

    def obj (Model):
        cx = 0
        fdy = 0
        fvx = 0
        for i in Model.n :
            for j in Model.n :
                cx += Model.c[i,j]*Model.x[i,j]
        for k in Model.n0 :
            fdy += Model.fd[k] * Model.y[k]
        for k in Model.n0 :
            for i in Model.nc :
                fvx += fv * Model.x[k,i]
        return cx + fdy + fvx
    Model.objective = Objective(rule=obj)
    print('!'*60)

    def pyomo_postprocess(options=None, instance=None, results=None):
        Model.objective.display()
        

    #This is an optional code path that allows the script to be run outside of
    #pyomo command-line.  For example:  python transport.py
    if __name__ == '__main__':
       # This emulates what the pyomo command-line tools does
        from pyomo.opt import SolverFactory
    #   import pyomo.environ
        opt = SolverFactory("glpk")
        results = opt.solve(Model)
        #sends results to stdout
        results.write()
        print("\nDisplaying Solution\n" + '!'*60)
        pyomo_postprocess(None, Model, results)
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 744.890426317549
#   Upper bound: 744.890426317549
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 137
#       Number of created subproblems: 137
#   Error rc: 0
#   Time: 0.1280226707458496
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 744.8904263175488
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: infeasible
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 15
#       Number of created subproblems: 15
#   Error rc: 0
#   Time: 0.10399246215820312
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
# ERROR: evaluating expression: No value for uninitialized NumericValue object
#     x[1,2]
#         (expression: 31.064449134018133*x[1,2] + 32.69556544854363*x[1,3] +
#         38.41874542459709*x[1,4] + 21.18962010041709*x[1,5] + 36.0*x[1,6] +
#         30.805843601498726*x[1,7] + 3.0*x[1,8] + 43.01162633521314*x[1,9] +
#         36.22154055254967*x[1,10] + 32.31098884280702*x[1,11] +
#         38.07886552931954*x[1,12] + 21.2602916254693*x[1,13] +
#         31.064449134018133*x[2,1] + 36.71511950137164*x[2,3] +
#         32.7566787083184*x[2,4] + 14.212670403551895*x[2,5] +
#         5.385164807134504*x[2,6] + 40.0*x[2,7] + 34.058772731852805*x[2,8] +
#         27.294688127912362*x[2,9] + 7.810249675906654*x[2,10] +
#         14.035668847618199*x[2,11] + 21.095023109728988*x[2,12] +
#         19.209372712298546*x[2,13] + 32.69556544854363*x[3,1] +
#         36.71511950137164*x[3,2] + 11.0*x[3,4] + 24.041630560342615*x[3,5] +
#         37.8021163428716*x[3,6] + 6.0*x[3,7] + 34.0*x[3,8] +
#         22.561028345356956*x[3,9] + 34.713109915419565*x[3,10] +
#         24.758836806279895*x[3,11] + 22.825424421026653*x[3,12] +
#         44.10215414239989*x[3,13] + 38.41874542459709*x[4,1] +
#         32.7566787083184*x[4,2] + 11.0*x[4,3] + 23.345235059857504*x[4,5] +
#         32.31098884280702*x[4,6] + 17.0*x[4,7] + 40.36087214122113*x[4,8] +
#         12.083045973594572*x[4,9] + 28.635642126552707*x[4,10] +
#         18.973665961010276*x[4,11] + 14.212670403551895*x[4,12] +
#         44.721359549995796*x[4,13] + 21.18962010041709*x[5,1] +
#         14.212670403551895*x[5,2] + 24.041630560342615*x[5,3] +
#         23.345235059857504*x[5,4] + 17.46424919657298*x[5,6] +
#         26.419689627245813*x[5,7] + 24.041630560342615*x[5,8] +
#         23.430749027719962*x[5,9] + 16.278820596099706*x[5,10] +
#         11.180339887498949*x[5,11] + 17.69180601295413*x[5,12] +
#         21.37755832643195*x[5,13] + 36.0*x[6,1] + 5.385164807134504*x[6,2] +
#         37.8021163428716*x[6,3] + 32.31098884280702*x[6,4] +
#         17.46424919657298*x[6,5] + 41.72529209005013*x[6,7] + 39.0*x[6,8] +
#         25.019992006393608*x[6,9] + 4.0*x[6,10] + 13.416407864998739*x[6,11] +
#         19.235384061671343*x[6,12] + 24.413111231467404*x[6,13] +
#         30.805843601498726*x[7,1] + 40.0*x[7,2] + 6.0*x[7,3] + 17.0*x[7,4] +
#         26.419689627245813*x[7,5] + 41.72529209005013*x[7,6] +
#         31.622776601683793*x[7,8] + 28.442925306655784*x[7,9] +
#         38.948684188300895*x[7,10] + 29.206163733020468*x[7,11] +
#         28.231188426986208*x[7,12] + 44.91102314577124*x[7,13] + 3.0*x[8,1] +
#         34.058772731852805*x[8,2] + 34.0*x[8,3] + 40.36087214122113*x[8,4] +
#         24.041630560342615*x[8,5] + 39.0*x[8,6] + 31.622776601683793*x[8,7] +
#         45.48626166217664*x[8,9] + 39.20459156782532*x[8,10] +
#         35.11409973215888*x[8,11] + 40.70626487409524*x[8,12] +
#         23.600847442411894*x[8,13] + 43.01162633521314*x[9,1] +
#         27.294688127912362*x[9,2] + 22.561028345356956*x[9,3] +
#         12.083045973594572*x[9,4] + 23.430749027719962*x[9,5] +
#         25.019992006393608*x[9,6] + 28.442925306655784*x[9,7] +
#         45.48626166217664*x[9,8] + 21.02379604162864*x[9,10] +
#         13.92838827718412*x[9,11] + 6.324555320336759*x[9,12] +
#         43.382023926967726*x[9,13] + 36.22154055254967*x[10,1] +
#         7.810249675906654*x[10,2] + 34.713109915419565*x[10,3] +
#         28.635642126552707*x[10,4] + 16.278820596099706*x[10,5] + 4.0*x[10,6]
#         + 38.948684188300895*x[10,7] + 39.20459156782532*x[10,8] +
#         21.02379604162864*x[10,9] + 10.0*x[10,11] +
#         15.297058540778355*x[10,12] + 26.90724809414742*x[10,13] +
#         32.31098884280702*x[11,1] + 14.035668847618199*x[11,2] +
#         24.758836806279895*x[11,3] + 18.973665961010276*x[11,4] +
#         11.180339887498949*x[11,5] + 13.416407864998739*x[11,6] +
#         29.206163733020468*x[11,7] + 35.11409973215888*x[11,8] +
#         13.92838827718412*x[11,9] + 10.0*x[11,10] + 7.615773105863909*x[11,12]
#         + 29.5296461204668*x[11,13] + 38.07886552931954*x[12,1] +
#         21.095023109728988*x[12,2] + 22.825424421026653*x[12,3] +
#         14.212670403551895*x[12,4] + 17.69180601295413*x[12,5] +
#         19.235384061671343*x[12,6] + 28.231188426986208*x[12,7] +
#         40.70626487409524*x[12,8] + 6.324555320336759*x[12,9] +
#         15.297058540778355*x[12,10] + 7.615773105863909*x[12,11] +
#         37.12142238654117*x[12,13] + 21.2602916254693*x[13,1] +
#         19.209372712298546*x[13,2] + 44.10215414239989*x[13,3] +
#         44.721359549995796*x[13,4] + 21.37755832643195*x[13,5] +
#         24.413111231467404*x[13,6] + 44.91102314577124*x[13,7] +
#         23.600847442411894*x[13,8] + 43.382023926967726*x[13,9] +
#         26.90724809414742*x[13,10] + 29.5296461204668*x[13,11] +
#         37.12142238654117*x[13,12] + 39*y[1] + 26*y[2] + 14*y[3] + 20*x[1,4] +
#         20*x[1,5] + 20*x[1,6] + 20*x[1,7] + 20*x[1,8] + 20*x[1,9] + 20*x[1,10]
#         + 20*x[1,11] + 20*x[1,12] + 20*x[1,13] + 20*x[2,4] + 20*x[2,5] +
#         20*x[2,6] + 20*x[2,7] + 20*x[2,8] + 20*x[2,9] + 20*x[2,10] +
#         20*x[2,11] + 20*x[2,12] + 20*x[2,13] + 20*x[3,4] + 20*x[3,5] +
#         20*x[3,6] + 20*x[3,7] + 20*x[3,8] + 20*x[3,9] + 20*x[3,10] +
#         20*x[3,11] + 20*x[3,12] + 20*x[3,13])
# ERROR: evaluating object as numeric value: objective
#         (object: <class 'pyomo.core.base.objective.SimpleObjective'>)
#     No value for uninitialized NumericValue object x[1,2]
#     Key : Active : Value
#     None :   None :  None
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 610.782895861122
#   Upper bound: 610.782895861122
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1939
#       Number of created subproblems: 1939
#   Error rc: 0
#   Time: 0.48398590087890625
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 610.7828958611221
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 968.130777538715
#   Upper bound: 968.130777538715
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 327
#       Number of created subproblems: 327
#   Error rc: 0
#   Time: 0.1619892120361328
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 968.1307775387154
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 987.079501654766
#   Upper bound: 987.079501654766
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 129
#       Number of created subproblems: 129
#   Error rc: 0
#   Time: 0.11300086975097656
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 987.0795016547662
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 657.549628458175
#   Upper bound: 657.549628458175
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 87
#       Number of created subproblems: 87
#   Error rc: 0
#   Time: 0.09997987747192383
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 657.5496284581745
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 756.567647868908
#   Upper bound: 756.567647868908
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 755
#       Number of created subproblems: 755
#   Error rc: 0
#   Time: 0.21000146865844727
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 756.5676478689078
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: infeasible
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 96055
#       Number of created subproblems: 96055
#   Error rc: 0
#   Time: 27.697980403900146
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
# ERROR: evaluating expression: No value for uninitialized NumericValue object
#     x[1,2]
#         (expression: 30.0*x[1,2] + 39.56008088970496*x[1,3] +
#         41.400483088968905*x[1,4] + 23.430749027719962*x[1,5] +
#         18.027756377319946*x[1,6] + 21.2602916254693*x[1,7] + 4.0*x[1,8] +
#         38.01315561749642*x[1,9] + 30.610455730027933*x[1,10] +
#         19.313207915827967*x[1,11] + 16.0312195418814*x[1,12] + 16.0*x[1,13] +
#         30.0*x[2,1] + 21.470910553583888*x[2,3] + 15.033296378372908*x[2,4] +
#         9.0*x[2,5] + 29.410882339705484*x[2,6] + 40.19950248448356*x[2,7] +
#         26.90724809414742*x[2,8] + 30.479501308256342*x[2,9] + x[2,10] +
#         12.529964086141668*x[2,11] + 20.615528128088304*x[2,12] +
#         24.08318915758459*x[2,13] + 39.56008088970496*x[3,1] +
#         21.470910553583888*x[3,2] + 11.704699910719626*x[3,4] +
#         19.026297590440446*x[3,5] + 47.01063709417264*x[3,6] +
#         37.8021163428716*x[3,7] + 38.3275357934736*x[3,8] +
#         13.038404810405298*x[3,9] + 20.591260281974*x[3,10] +
#         30.265491900843113*x[3,11] + 38.05259518088089*x[3,12] +
#         25.238858928247925*x[3,13] + 41.400483088968905*x[4,1] +
#         15.033296378372908*x[4,2] + 11.704699910719626*x[4,3] +
#         18.027756377319946*x[4,5] + 44.14748010928823*x[4,6] +
#         45.18849411078001*x[4,7] + 39.11521443121589*x[4,8] +
#         24.515301344262525*x[4,9] + 14.035668847618199*x[4,10] +
#         26.92582403567252*x[4,11] + 35.17101079013795*x[4,12] +
#         30.23243291566195*x[4,13] + 23.430749027719962*x[5,1] + 9.0*x[5,2] +
#         19.026297590440446*x[5,3] + 18.027756377319946*x[5,4] + 28.0*x[5,6] +
#         31.25699921617557*x[5,7] + 21.095023109728988*x[5,8] +
#         24.413111231467404*x[5,9] + 9.055385138137417*x[5,10] +
#         11.40175425099138*x[5,11] + 19.026297590440446*x[5,12] +
#         15.132745950421556*x[5,13] + 18.027756377319946*x[6,1] +
#         29.410882339705484*x[6,2] + 47.01063709417264*x[6,3] +
#         44.14748010928823*x[6,4] + 28.0*x[6,5] + 39.20459156782532*x[6,7] +
#         14.866068747318506*x[6,8] + 50.0*x[6,9] + 30.364452901377952*x[6,10] +
#         17.26267650163207*x[6,11] + 9.055385138137417*x[6,12] +
#         30.01666203960727*x[6,13] + 21.2602916254693*x[7,1] +
#         40.19950248448356*x[7,2] + 37.8021163428716*x[7,3] +
#         45.18849411078001*x[7,4] + 31.25699921617557*x[7,5] +
#         39.20459156782532*x[7,6] + 24.413111231467404*x[7,8] +
#         29.410882339705484*x[7,9] + 40.311288741492746*x[7,10] +
#         34.713109915419565*x[7,11] + 35.34119409414458*x[7,12] +
#         16.1245154965971*x[7,13] + 4.0*x[8,1] + 26.90724809414742*x[8,2] +
#         38.3275357934736*x[8,3] + 39.11521443121589*x[8,4] +
#         21.095023109728988*x[8,5] + 14.866068747318506*x[8,6] +
#         24.413111231467404*x[8,7] + 38.118237105091836*x[8,9] +
#         27.586228448267445*x[8,10] + 15.652475842498529*x[8,11] +
#         12.041594578792296*x[8,12] + 16.492422502470642*x[8,13] +
#         38.01315561749642*x[9,1] + 30.479501308256342*x[9,2] +
#         13.038404810405298*x[9,3] + 24.515301344262525*x[9,4] +
#         24.413111231467404*x[9,5] + 50.0*x[9,6] + 29.410882339705484*x[9,7] +
#         38.118237105091836*x[9,8] + 29.832867780352597*x[9,10] +
#         35.35533905932738*x[9,11] + 41.78516483155236*x[9,12] +
#         22.02271554554524*x[9,13] + 30.610455730027933*x[10,1] + x[10,2] +
#         20.591260281974*x[10,3] + 14.035668847618199*x[10,4] +
#         9.055385138137417*x[10,5] + 30.364452901377952*x[10,6] +
#         40.311288741492746*x[10,7] + 27.586228448267445*x[10,8] +
#         29.832867780352597*x[10,9] + 13.416407864998739*x[10,11] +
#         21.540659228538015*x[10,12] + 24.186773244895647*x[10,13] +
#         19.313207915827967*x[11,1] + 12.529964086141668*x[11,2] +
#         30.265491900843113*x[11,3] + 26.92582403567252*x[11,4] +
#         11.40175425099138*x[11,5] + 17.26267650163207*x[11,6] +
#         34.713109915419565*x[11,7] + 15.652475842498529*x[11,8] +
#         35.35533905932738*x[11,9] + 13.416407864998739*x[11,10] +
#         8.246211251235321*x[11,12] + 20.12461179749811*x[11,13] +
#         16.0312195418814*x[12,1] + 20.615528128088304*x[12,2] +
#         38.05259518088089*x[12,3] + 35.17101079013795*x[12,4] +
#         19.026297590440446*x[12,5] + 9.055385138137417*x[12,6] +
#         35.34119409414458*x[12,7] + 12.041594578792296*x[12,8] +
#         41.78516483155236*x[12,9] + 21.540659228538015*x[12,10] +
#         8.246211251235321*x[12,11] + 23.345235059857504*x[12,13] +
#         16.0*x[13,1] + 24.08318915758459*x[13,2] + 25.238858928247925*x[13,3]
#         + 30.23243291566195*x[13,4] + 15.132745950421556*x[13,5] +
#         30.01666203960727*x[13,6] + 16.1245154965971*x[13,7] +
#         16.492422502470642*x[13,8] + 22.02271554554524*x[13,9] +
#         24.186773244895647*x[13,10] + 20.12461179749811*x[13,11] +
#         23.345235059857504*x[13,12] + 22*y[1] + 29*y[2] + 48*y[3] + 20*x[1,4]
#         + 20*x[1,5] + 20*x[1,6] + 20*x[1,7] + 20*x[1,8] + 20*x[1,9] +
#         20*x[1,10] + 20*x[1,11] + 20*x[1,12] + 20*x[1,13] + 20*x[2,4] +
#         20*x[2,5] + 20*x[2,6] + 20*x[2,7] + 20*x[2,8] + 20*x[2,9] + 20*x[2,10]
#         + 20*x[2,11] + 20*x[2,12] + 20*x[2,13] + 20*x[3,4] + 20*x[3,5] +
#         20*x[3,6] + 20*x[3,7] + 20*x[3,8] + 20*x[3,9] + 20*x[3,10] +
#         20*x[3,11] + 20*x[3,12] + 20*x[3,13])
# ERROR: evaluating object as numeric value: objective
#         (object: <class 'pyomo.core.base.objective.SimpleObjective'>)
#     No value for uninitialized NumericValue object x[1,2]
#     Key : Active : Value
#     None :   None :  None
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 737.409950179398
#   Upper bound: 737.409950179398
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1593
#       Number of created subproblems: 1593
#   Error rc: 0
#   Time: 0.3920016288757324
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 737.4099501793983
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 820.686868703702
#   Upper bound: 820.686868703702
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1081
#       Number of created subproblems: 1081
#   Error rc: 0
#   Time: 0.3729681968688965
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 820.6868687037025
# Wall time: 34.4 s

# %%
# %%time

from __future__ import division

from pyomo.environ import *

import random as ra

for l in range(10):
    

    Model = ConcreteModel()

    costumers = 10

    depots = 3

    nodes = costumers + depots

    Model.n =  RangeSet(1,nodes)

    Model.n0 = set (i for i in Model.n if i <= depots)

    Model.nc = set (i for i in Model.n if i > depots )




    #def x1  (Model,i):
    #    return ra.randint(50,150)
    #Model.x1 = Param( Model.n , initialize = x1)

    x1 = {}
    for i in Model.n:
        x1[i] = ra.randint(50,100)
    Model.x1 = Param(Model.n,initialize = x1)


    #def y1 (Model,i):
    #    return ra.randint(50,150)
    #Model.y1 = Param(Model.n,initialize = y1)

    y1 = {}
    for i in Model.n:
         y1[i] = ra.randint(50,100)
    Model.y1 = Param(Model.n,initialize = y1)


    #def d (Model,i):
    #    return ra.randint(50,150)
    #Model.d = Param(Model.nc,initialize = d)

    d = {}
    for i in Model.nc :
    #    if i > depots :
            d[i] = ra.randint(50,100)
    Model.d = Param(Model.nc,initialize = d)

    #def p (Model,i):
    #    return ra.randint(50,150)
    #Model.p = Param(Model.nc,initialize = p)

    p = {}
    for i in Model.nc :
    #    if i > depots :
            p[i] = ra.randint(50,100)
    Model.p = Param(Model.nc,initialize = p)


    #def fd (Model,i):
    #    return ra.randint(50,100)
    #Model.p = Param(Model.n0,initialize = fd)

    fd ={}
    for i in Model.n0 :
    #    if i <depots+1:
            fd[i] = ra.randint(10,50)
    Model.fd = Param(Model.n0,initialize = fd)



    cd = 500

    cv = 200

    fv =20

    def c  (Model,i,j):
        return ((x1[i]-x1[j])**2+ (y1[i]-y1[j])**2)**0.5
    Model.c = Param( Model.n,Model.n , initialize = c)

    #c ={}
    #for i in Model.n:
    #    for j in Model.n:
    #                c[i,j] = ((x1[i]-x1[j])**2+ (y1[i]-y1[j])**2)**0.5
    #
    #Model.c = Param(Model.n,Model.n ,initialize = c)

    #Model.zz = Var(within = Reals)
    #Model.z3 =set( Model.nc , Model.n0)

    Model.x  = Var(Model.n , Model.n , within = Binary)

    Model.y = Var(Model.n0  , within = Binary)

    Model.z = Var(Model.nc , Model.n0  , within = Binary)
  

    Model.v = Var(Model.n,Model.n , within = PositiveReals)

    Model.u = Var(Model.n,Model.n , within = PositiveReals)

    #for i in Model.n:
    #    for k in Model.n:
    #        Model.z =

    def _2 (Model,i):
        xij=0
        for j in Model.n:
            xij+=Model.x[i,j]
            return xij ==1
    Model._2 = Constraint(Model.nc,rule =_2)

    #def _2 (Model):
    #
    #    for i in Model.nc:
    #        xij=0
    #       for j in Model.n:
    #           xij+=Model.x[i,j]
    #        return xij ==1
    #Model._2 = Constraint(rule =_2)

    def _3 (Model,i):
        xij = 0
        xji = 0
        for j in Model.n:
            xij+=Model.x[i,j]
            xji+=Model.x[j,i]
            return xij == xji
    Model._3 = Constraint(Model.n,rule =_3)


    #def _3 (Model):
    #    for i in Model.n:
    #        xij=0
    #        xji=0
    #        for j in Model.n:
    #            xij+=Model.x[i,j]
    #            xji+=Model.x[j,i]
    #        return xij ==xji
    #Model._3 = Constraint(rule =_3)

    def _4 (Model,i):

            uij = 0
            uji = 0
            for j in Model.n:
                uji +=Model.u[j,i]
                uij +=Model.u[i,j]
            return uji - uij == Model.d[i]
    Model._4 = Constraint(Model.nc,rule =_4)

    #def _4 (Model):
    #    for i in Model.nc:
    #        uij = 0
    #        uji = 0
    #        for j in Model.n:
    #            uji +=Model.u[j,i]
    #            uij +=Model.u[i,j]
    #        return uji - uij == Model.d[i]
    #Model._4 = Constraint(rule =_4)

    def _5 (Model,i):

            vij = 0
            vji = 0
            for j in Model.n:
                vji +=Model.v[j,i]
                vij +=Model.v[i,j]
            return vji - vij == Model.p[i]
    Model._5 = Constraint(Model.nc,rule =_5)

    #def _5 (Model):
    #    for i in Model.nc:
    #        vij = 0
    #        vji = 0
    #        for j in Model.n:
    #            vji +=Model.v[j,i]
    #            vij +=Model.v[i,j]
    #        return vji - vij == Model.p[i]
    #Model._5 = Constraint(rule =_5)

    def _6 (Model,i):
        for j in Model.n:
                if i!= j:
                    return  Model.u[i,j] + Model.v[i,j] <=cv * Model.x[i,j]
    Model._6 = Constraint(Model.n,rule =_6)

    #def _6 (Model):
    #    for i in Model.n:
    #        for j in Model.n:
    #            if i!= j:
    #                return  Model.u[i,j] + Model.v[i,j] <=cv * Model.x[i,j]
    #Model._6 = Constraint(rule =_6)

    def _7 (Model,k):

            ukj = 0
            zjkdj = 0
            for j in Model.nc:
                ukj += Model.u[k,j]
                zjkdj +=Model.z[j,k]*Model.d[j]
            return ukj == zjkdj
    Model._7 = Constraint(Model.n0,rule =_7)

    #def _7 (Model):
    #    for k in Model.nc:
    #        ukj = 0
    #        zjkdj = 0
    #        for j in Model.nc:
    #            ukj += Model.u[k,j]
    #            zjkdj +=Model.z[j,k]*Model.d[j]
    #        return ukj == zjkdj
    #Model._7 = Constraint(rule =_7)

    def _8 (Model,k):


            ujk=0
            for j in Model.nc:
                ujk+=Model.u[j,k]
            return ujk == 0
    Model._8 = Constraint(Model.n0,rule =_8)

    #def _8 (Model):
    #
    #    for k in Model.n0:
    #        ujk=0
    #        for j in Model.nc:
    #            ujk+=Model.u[j,k]
    #        return ujk == 0
    #Model._8 = Constraint(rule =_8)

    #def _9 (Model,k):
    #    vjk = 0
    #    zjkpj = 0
    #    for j in Model.nc:
    #        vjk += Model.u[k,j]
    #        zjkpj += Model.z[j,k]*Model.p[j]
    #    return vjk == zjkpj
    #Model._9 = Constraint(Model.n0,rule =_9)

    def _9 (Model):
        for k in Model.n0:
            vjk = 0
            zjkpj = 0
            for j in Model.nc:
                vjk += Model.u[k,j]
                zjkpj +=Model.z[j,k]*Model.p[j]
            return vjk == zjkpj
    Model._9 = Constraint(rule =_9)

    #def _10 (Model,k):
    #
    #        vjk=0
    #        for j in Model.nc:
    #            vjk+=Model.v[j,k]
    #        return vjk == 0
    #Model._10 = Constraint(Model.n0,rule =_10)

    def _10 (Model,k):


            vjk=0
            for j in Model.nc:
                vjk+=Model.v[j,k]
            return vjk == 0
    Model._10 = Constraint(Model.n0,rule =_10)

    #def _10 (Model):
    #
    #    for k in Model.n0:
    #        vjk=0
    #        for j in Model.nc:
    #            vjk+=Model.v[j,k]
    #        return vjk == 0
    #Model._10 = Constraint(rule =_10)

    def _11 (Model,i,j):

                return Model.u[i,j] <= (cv - Model.d[i])* Model.x[i,j]
    Model._11 = Constraint(Model.nc,Model.n,rule =_11)



    #def _11 (Model):
    #    for j in Model.n:
    #        for i in Model.nc:
    #            return Model.u[i,j] <= (cv - Model.d[i])* Model.x[i,j]
    #Model._11 = Constraint(rule =_11)

    def _12 (Model,i,j):

                return Model.v[i,j] <= (cv - Model.p[i])* Model.x[i,j]
    Model._12 = Constraint(Model.nc,Model.n,rule =_12)

    #def _12 (Model):
    #    for i in Model.nc:
    #        for j in Model.n:
    #            return Model.v[i,j] <= (cv - Model.p[i])* Model.x[i,j]
    #Model._12 = Constraint(rule =_12)

    #def _13 (Model,i):
    #    for j in Model.nc:
    #            return Model.u[i,j] >= Model.d[j]*Model.x[i,j]
    #Model._13 = Constraint(Model.n,rule =_13)

    def _13 (Model):
        for j in Model.nc:
            for i in Model.n:
                return Model.u[i,j] >= Model.d[j]*Model.x[i,j]
    Model._13 = Constraint(rule =_13)

    #def _14 (Model,i,j):
    #
    #            return Model.u[i,j] >= Model.d[j]*Model.x[i,j]
    #Model._14 = Constraint(Model.nc,Model.n,rule =_14)

    def _14 (Model):
        for j in Model.nc:
            for i in Model.n:
                return Model.v[i,j] >= Model.p[j] * Model.x[i,j]
    Model._14 = Constraint(rule =_14)

    def _15 (Model):

        for i in Model.nc:
            zik=0
            for k in Model.n0:
                zik += Model.z[i,k]
            return zik == 1
    Model._15 = Constraint(rule =_15)

    def _16 (Model):
        for k in Model.n0:
            dizik = 0
            for i in Model.nc:
                dizik += Model.d[i] * Model.z[i,k]
            return dizik <=cd * Model.y[k]
    Model._16 = Constraint(rule =_16)

    def _17 (Model):
        for k in Model.n0:
            pizik = 0
            for i in Model.nc:
                pizik += Model.d[i] * Model.z[i,k]
            return pizik <=cd * Model.y[k]
    Model._17 = Constraint(rule =_17)

    def _18 (Model):
        for k in Model.n0:
            for i in Model.nc:
                return Model.x[i,k] <= Model.z[i,k]
    Model._18 = Constraint(rule =_18)

    def _19 (Model):
        for k in Model.n0:
            for i in Model.nc:
                return Model.x[k,i] <= Model.z[i,k]
    Model._19 = Constraint(rule =_19)

    def _20 (Model):
        for k in Model.n0:
            for i in Model.nc:
                for j in Model.nc:
                    if i!=j :

                        zjm = 0
                        for m in Model.n0:
                            if m != k:
                                zjm += Model.z[j,m]
                        return Model.x[i,j]+Model.z[i,k] + zjm <=2
    Model._20 = Constraint(rule =_20)

    def obj (Model):
        cx = 0
        fdy = 0
        fvx = 0
        for i in Model.n :
            for j in Model.n :
                cx += Model.c[i,j]*Model.x[i,j]
        for k in Model.n0 :
            fdy += Model.fd[k] * Model.y[k]
        for k in Model.n0 :
            for i in Model.nc :
                fvx += fv * Model.x[k,i]
        return cx + fdy + fvx
    Model.objective = Objective(rule=obj)
    print('!'*60)

    def pyomo_postprocess(options=None, instance=None, results=None):
        Model.objective.display()
        

    #This is an optional code path that allows the script to be run outside of
    #pyomo command-line.  For example:  python transport.py
    if __name__ == '__main__':
       # This emulates what the pyomo command-line tools does
        from pyomo.opt import SolverFactory
    #   import pyomo.environ
        opt = SolverFactory("glpk")
        results = opt.solve(Model)
        #sends results to stdout
        results.write()
        print("\nDisplaying Solution\n" + '!'*60)
        pyomo_postprocess(None, Model, results)
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 923.995298017439
#   Upper bound: 923.995298017439
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 573
#       Number of created subproblems: 573
#   Error rc: 0
#   Time: 0.20098495483398438
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 923.9952980174395
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 688.904726756116
#   Upper bound: 688.904726756116
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 687
#       Number of created subproblems: 687
#   Error rc: 0
#   Time: 0.22797751426696777
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 688.9047267561159
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: infeasible
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.0769798755645752
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
# ERROR: evaluating expression: No value for uninitialized NumericValue object
#     x[1,2]
#         (expression: 15.652475842498529*x[1,2] + 25.495097567963924*x[1,3] +
#         7.810249675906654*x[1,4] + 5.385164807134504*x[1,5] +
#         29.832867780352597*x[1,6] + 18.973665961010276*x[1,7] +
#         24.698178070456937*x[1,8] + 12.36931687685298*x[1,9] +
#         27.018512172212592*x[1,10] + 24.596747752497688*x[1,11] +
#         24.73863375370596*x[1,12] + 24.041630560342615*x[1,13] +
#         15.652475842498529*x[2,1] + 39.05124837953327*x[2,3] +
#         14.422205101855956*x[2,4] + 12.727922061357855*x[2,5] +
#         44.598206241955516*x[2,6] + 32.01562118716424*x[2,7] +
#         30.4138126514911*x[2,8] + 17.72004514666935*x[2,9] +
#         36.40054944640259*x[2,10] + 29.154759474226502*x[2,11] +
#         40.162171256046406*x[2,12] + 17.46424919657298*x[2,13] +
#         25.495097567963924*x[3,1] + 39.05124837953327*x[3,2] +
#         24.758836806279895*x[3,4] + 26.40075756488817*x[3,5] + 8.0*x[3,6] +
#         7.0710678118654755*x[3,7] + 44.04543109109048*x[3,8] +
#         35.90264614203248*x[3,9] + 41.23105625617661*x[3,10] +
#         22.02271554554524*x[3,11] + 21.400934559032695*x[3,12] +
#         49.39635614091387*x[3,13] + 7.810249675906654*x[4,1] +
#         14.422205101855956*x[4,2] + 24.758836806279895*x[4,3] +
#         3.1622776601683795*x[4,5] + 30.805843601498726*x[4,6] +
#         17.69180601295413*x[4,7] + 32.202484376209235*x[4,8] +
#         19.235384061671343*x[4,9] + 34.828149534535996*x[4,10] +
#         17.72004514666935*x[4,11] + 30.01666203960727*x[4,12] +
#         28.0178514522438*x[4,13] + 5.385164807134504*x[5,1] +
#         12.727922061357855*x[5,2] + 26.40075756488817*x[5,3] +
#         3.1622776601683795*x[5,4] + 31.89043743820395*x[5,6] +
#         19.4164878389476*x[5,7] + 29.206163733020468*x[5,8] +
#         16.1245154965971*x[5,9] + 32.202484376209235*x[5,10] +
#         20.8806130178211*x[5,11] + 29.274562336608895*x[5,12] +
#         25.079872407968907*x[5,13] + 29.832867780352597*x[6,1] +
#         44.598206241955516*x[6,2] + 8.0*x[6,3] + 30.805843601498726*x[6,4] +
#         31.89043743820395*x[6,5] + 13.92838827718412*x[6,7] +
#         44.40720662234904*x[6,8] + 38.48376280978771*x[6,9] +
#         40.049968789001575*x[6,10] + 30.01666203960727*x[6,11] +
#         17.72004514666935*x[6,12] + 52.839379254491625*x[6,13] +
#         18.973665961010276*x[7,1] + 32.01562118716424*x[7,2] +
#         7.0710678118654755*x[7,3] + 17.69180601295413*x[7,4] +
#         19.4164878389476*x[7,5] + 13.92838827718412*x[7,6] +
#         39.6232255123179*x[7,8] + 30.14962686336267*x[7,9] +
#         38.07886552931954*x[7,10] + 17.46424919657298*x[7,11] +
#         21.633307652783937*x[7,12] + 43.01162633521314*x[7,13] +
#         24.698178070456937*x[8,1] + 30.4138126514911*x[8,2] +
#         44.04543109109048*x[8,3] + 32.202484376209235*x[8,4] +
#         29.206163733020468*x[8,5] + 44.40720662234904*x[8,6] +
#         39.6232255123179*x[8,7] + 13.45362404707371*x[8,9] +
#         8.94427190999916*x[8,10] + 49.24428900898052*x[8,11] +
#         29.154759474226502*x[8,12] + 20.09975124224178*x[8,13] +
#         12.36931687685298*x[9,1] + 17.72004514666935*x[9,2] +
#         35.90264614203248*x[9,3] + 19.235384061671343*x[9,4] +
#         16.1245154965971*x[9,5] + 38.48376280978771*x[9,6] +
#         30.14962686336267*x[9,7] + 13.45362404707371*x[9,8] +
#         18.681541692269406*x[9,10] + 36.76955262170047*x[9,11] +
#         27.65863337187866*x[9,12] + 14.866068747318506*x[9,13] +
#         27.018512172212592*x[10,1] + 36.40054944640259*x[10,2] +
#         41.23105625617661*x[10,3] + 34.828149534535996*x[10,4] +
#         32.202484376209235*x[10,5] + 40.049968789001575*x[10,6] +
#         38.07886552931954*x[10,7] + 8.94427190999916*x[10,8] +
#         18.681541692269406*x[10,9] + 50.44799302251776*x[10,11] +
#         23.194827009486403*x[10,12] + 28.635642126552707*x[10,13] +
#         24.596747752497688*x[11,1] + 29.154759474226502*x[11,2] +
#         22.02271554554524*x[11,3] + 17.72004514666935*x[11,4] +
#         20.8806130178211*x[11,5] + 30.01666203960727*x[11,6] +
#         17.46424919657298*x[11,7] + 49.24428900898052*x[11,8] +
#         36.76955262170047*x[11,9] + 50.44799302251776*x[11,10] +
#         38.48376280978771*x[11,12] + 45.17742799230607*x[11,13] +
#         24.73863375370596*x[12,1] + 40.162171256046406*x[12,2] +
#         21.400934559032695*x[12,3] + 30.01666203960727*x[12,4] +
#         29.274562336608895*x[12,5] + 17.72004514666935*x[12,6] +
#         21.633307652783937*x[12,7] + 29.154759474226502*x[12,8] +
#         27.65863337187866*x[12,9] + 23.194827009486403*x[12,10] +
#         38.48376280978771*x[12,11] + 42.44997055358225*x[12,13] +
#         24.041630560342615*x[13,1] + 17.46424919657298*x[13,2] +
#         49.39635614091387*x[13,3] + 28.0178514522438*x[13,4] +
#         25.079872407968907*x[13,5] + 52.839379254491625*x[13,6] +
#         43.01162633521314*x[13,7] + 20.09975124224178*x[13,8] +
#         14.866068747318506*x[13,9] + 28.635642126552707*x[13,10] +
#         45.17742799230607*x[13,11] + 42.44997055358225*x[13,12] + 34*y[1] +
#         37*y[2] + 27*y[3] + 20*x[1,4] + 20*x[1,5] + 20*x[1,6] + 20*x[1,7] +
#         20*x[1,8] + 20*x[1,9] + 20*x[1,10] + 20*x[1,11] + 20*x[1,12] +
#         20*x[1,13] + 20*x[2,4] + 20*x[2,5] + 20*x[2,6] + 20*x[2,7] + 20*x[2,8]
#         + 20*x[2,9] + 20*x[2,10] + 20*x[2,11] + 20*x[2,12] + 20*x[2,13] +
#         20*x[3,4] + 20*x[3,5] + 20*x[3,6] + 20*x[3,7] + 20*x[3,8] + 20*x[3,9]
#         + 20*x[3,10] + 20*x[3,11] + 20*x[3,12] + 20*x[3,13])
# ERROR: evaluating object as numeric value: objective
#         (object: <class 'pyomo.core.base.objective.SimpleObjective'>)
#     No value for uninitialized NumericValue object x[1,2]
#     Key : Active : Value
#     None :   None :  None
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 740.482021434186
#   Upper bound: 740.482021434186
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 4281
#       Number of created subproblems: 4281
#   Error rc: 0
#   Time: 1.3320000171661377
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 740.4820214341855
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 815.271320516066
#   Upper bound: 815.271320516066
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 53
#       Number of created subproblems: 53
#   Error rc: 0
#   Time: 0.08898520469665527
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 815.271320516066
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 856.585237472848
#   Upper bound: 856.585237472848
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 59
#       Number of created subproblems: 59
#   Error rc: 0
#   Time: 0.08899950981140137
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 856.5852374728479
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 780.153690144791
#   Upper bound: 780.153690144791
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 175
#       Number of created subproblems: 175
#   Error rc: 0
#   Time: 0.1309974193572998
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 780.153690144791
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 972.550432331237
#   Upper bound: 972.550432331237
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 23
#       Number of created subproblems: 23
#   Error rc: 0
#   Time: 0.1019899845123291
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 972.5504323312373
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 741.725095531534
#   Upper bound: 741.725095531534
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 375
#       Number of created subproblems: 375
#   Error rc: 0
#   Time: 0.193009614944458
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 741.7250955315335
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 637.015114300427
#   Upper bound: 637.015114300427
#   Number of objectives: 1
#   Number of constraints: 335
#   Number of variables: 527
#   Number of nonzeros: 1251
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 187
#       Number of created subproblems: 187
#   Error rc: 0
#   Time: 0.14001750946044922
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
#
# Displaying Solution
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# objective : Size=1, Index=None, Active=True
#     Key  : Active : Value
#     None :   True : 637.0151143004268
# Wall time: 3.35 s
